# %%
from bokeh.plotting import figure, output_file, show

# %%
x = [1, 3, 5, 7]
y = [2, 4, 6, 8]

# %%
p = figure()
p.circle(x, y, size=10, color = 'red', legend = 'circle')
p.line(x, y, color = 'blue', legend = 'line')
p.triangle(y, x, color = 'gold', size = 10, legend = 'triangle')
# Out:
# ...
# GlyphRenderer(id='1397', ...)

# %%
p.legend.click_policy='hide'

# %%
show(p)

# %%
output_file('my_first_graph.html')

# %%
import bkcharts
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-13-438b7b6f14aa> in <module>
# ----> 1 from bkcharts import Bar, output_file, show
#
# C:\ProgramData\Anaconda3\lib\site-packages\bkcharts\__init__.py in <module>
#       3
#       4 # defaults and constants
# ----> 5 from bokeh.plotting.helpers import DEFAULT_PALETTE; DEFAULT_PALETTE
#       6
#       7 # main components
#
# ImportError: cannot import name 'DEFAULT_PALETTE' from 'bokeh.plotting.helpers' (C:\ProgramData\Anaconda3\lib\site-packages\bokeh\plotting\helpers.py)

# %%
from bokeh.io import output_file, show
from bokeh.plotting import figure

output_file("bars.html")

fruits = ['Apples', 'Pears', 'Nectarines', 'Plums', 'Grapes', 'Strawberries']
counts = [5, 3, 4, 2, 4, 6]

p = figure(x_range=fruits, plot_height=250, title="Fruit Counts",
           toolbar_location=None, tools="")

p.vbar(x=fruits, top=counts, width=0.9)

p.xgrid.grid_line_color = None
p.y_range.start = 0

show(p)
# Out:
#   <div class="bk-root" id="57517d4b-51ee-4c56-bdd2-7836343ca154" data-root-id="2243"></div>

# %%
from bokeh.plotting import figure, output_file, show
p = figure(plot_width = 400, plot_height = 400)

# %%
p.square([2, 5, 6, 4], [2, 3, 2, 1, 2], size = 20, color = "navy")
show(p)

# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import HoverTool, BoxSelectTool

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1559">Loading BokehJS ...</span>
#     </div>

# %%
TOOLS = [BoxSelectTool(), HoverTool()]

# %%
p = figure(plot_width = 400, plot_height = 400, tools = TOOLS)
p.square([2, 5, 6, 4, 8], [2, 3, 2, 1, 2], size = 20, color = "blue", alpha = 0.5)
p.xaxis.axis_label = "X 축"
p.yaxis.axis_label = "Y 축"
show(p)
# Out:
#   <div class="bk-root" id="9ce5ccbc-1726-4ce7-a835-c89f042f7819" data-root-id="1991"></div>

# %%
from bokeh.io import output_file, show
from bokeh.layouts import column
from bokeh.plotting import figure

output_file("layout.html")

x = list(range(11))
y0 = x
y1 = [10 - i for i in x]
y2 = [abs(i - 5) for i in x]

s1 = figure(plot_width=250, plot_height=250, background_fill_color="#fafafa")
s1.circle(x, y0, size=12, color="#53777a", alpha=0.8)

s2 = figure(plot_width=250, plot_height=250, background_fill_color="#fafafa")
s2.triangle(x, y1, size=12, color="#c02942", alpha=0.8)

s3 = figure(plot_width=250, plot_height=250, background_fill_color="#fafafa")
s3.square(x, y2, size=12, color="#d95b43", alpha=0.8)

show(column(s1, s2, s3))
# Out:
#   <div class="bk-root" id="bed360c6-ee75-4784-a668-e10d58dfcffe" data-root-id="2617"></div>

# %%
from bokeh.io import output_file, show
from bokeh.layouts import column
from bokeh.plotting import figure

output_file("layout.html")

x = list(range(11))
y0 = x
y1 = [10 - i for i in x]
y2 = [abs(i - 5) for i in x]

s1 = figure(plot_width=250, plot_height=250, background_fill_color="#fafafa")
s1.circle(x, y0, size=12, color="#53777a", alpha=0.8)

s2 = figure(plot_width=250, plot_height=250, background_fill_color="#fafafa")
s2.triangle(x, y1, size=12, color="#c02942", alpha=0.8)

s3 = figure(plot_width=250, plot_height=250, background_fill_color="#fafafa")
s3.square(x, y2, size=12, color="#d95b43", alpha=0.8)

show(column(s1, s2, s3))
# Out:
#   <div class="bk-root" id="b6d891a5-58a7-4c70-92dc-58252abf93ed" data-root-id="3304"></div>

# %%
import seaborn as sns
import pandas as pd

# %%
sns.set(style = "ticks")

# %%
tips = pd.read_excel("Data_py/tips.xlsx")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import seaborn as sns

sns.set(style="ticks")
#tips = sns.load_dataset("tips")
tips = pd.read_excel("Data_py/tips.xlsx")
g=sns.relplot(x="total_bill", y="tip", hue="day", data=tips)

# %%
import matplotlib.pyplot as plt
ax = sns.scatterplot(x="total_bill", y="tip", hue="time", data=tips)

# %%
fmri = sns.load_dataset("fmri")
ax = sns.lineplot(x="timepoint", y="signal", hue="region", data=fmri)

# %%
exercise = sns.load_dataset("exercise")
g = sns.catplot(x="time", y="pulse", hue="kind", data=exercise)
#catagorical data를 level 단위로 시각화를 제공해줌

# %%
tips = sns.load_dataset("tips")
gx = sns.stripplot(x="sex", y="total_bill", hue="day", data=tips)

# %%
tips = sns.load_dataset("tips")
gx = sns.swarmplot(x="sex", y="total_bill", hue="day", data=tips)
#overlapping 을 안하도록 배치해줌

# %%
tips = sns.load_dataset("tips")
sns.set(style="whitegrid")
gx = sns.boxplot(x="time", y="tip", data=tips, order=["Dinner", "Lunch"])

# %%
tips = sns.load_dataset("tips")
ax = sns.violinplot(x="time", y="tip", hue="sex", data =tips, order=["Dinner", "Lunch"])

# %%
tips = sns.load_dataset("tips")
ax = sns.boxenplot(x="time", y="tip", data=tips, order=["Dinner", "Lunch"])
ax = sns.stripplot(x="time", y="tip", data=tips, order=["Dinner", "Lunch"], color="gray")

# %%
import seaborn as sns
from numpy import median

sns.set(style="whitegrid")
tips = sns.load_dataset("tips")
ax = sns.pointplot(x="day", y="tip", data=tips, estimator=median)

# %%
ax = sns.barplot(x="size", y="tip", data=tips, estimator=median)

# %%
titanic = sns.load_dataset("titanic")
ax = sns.countplot(x="class", hue="who", data=titanic)
#categorical bin에서 관찰자가 몇 명인지

# %%
import seaborn as sns
import numpy as np
import pandas as pd

sns.set()
np.random.seed(0)
x = np.random.randn(100)
x = pd.Series(x, name="x.variable")
ax = sns.distplot(x, hist=True)

# %%
sns.set(color_codes=True)
np.random.seed(10)
mean, cov = [0, 2],[(1, .5), (.5, 1)]

x, y = np.random.multivariate_normal(mean, cov, size=50).T
ax = sns.kdeplot(x, y)

# %%
sns.set()
np.random.seed(0)
x = np.random.randn(30)
ax = sns.kdeplot(x, shade=True, cut=0)
ax = sns.rugplot(x)

# %%
sns.set(color_codes=True)
tips = sns.load_dataset("tips")
g = sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips)

# %%
g = sns.regplot(x="size", y="tip", data=tips, x_estimator=np.median)

# %%
g = sns.residplot(x="total_bill", y="tip", data=tips, lowess=True, line_kws={'color':'red'})

# %%
sns.set()
flights = sns.load_dataset("flights")
flights = flights.pivot("month", "year", "passengers")
ax = sns.heatmap(flights, annot = True)
# 주로 요일별 시간대를 분석할 때 좋음
# heatmap은 중요한 가시화 기법!

# %%
flights = sns.load_dataset("flights")
flights
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %%
sns.set(color_codes=True)
iris = sns.load_dataset("iris")
species = iris.pop("species")
g = sns.clustermap(iris, row_cluster=False, vmin=0, vmax=10)

# %%
g = sns.FacetGrid(tips, col="time", row="smoker", hue="day")
g = g.map(plt.hist, "total_bill")

# %%
iris = sns.load_dataset("iris")
g = sns.pairplot(iris, hue="species")

# %%
sns.set()
iris = sns.load_dataset("iris")
g = sns.PairGrid(iris, hue="species")
g = g.map_diag(sns.kdeplot)
g = g.map_offdiag(plt.scatter)
g = g.add_legend()

# %%
sns.set(style="white", color_codes=True)
tips = sns.load_dataset("tips")
g = sns.jointplot(x="total_bill", y="tip", data=tips, kind="hex")
