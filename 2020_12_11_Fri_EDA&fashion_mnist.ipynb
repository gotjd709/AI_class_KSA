# %% [markdown]
# <a href="https://colab.research.google.com/github/gotjd709/AI_class_KSA/blob/main/2020_12_11_Fri_EDA%26fashion_mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd
df = pd.DataFrame()
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-f8c86a5839b4> in <module>()
#       1 import seaborn as sns
#       2 import pandas as pd
# ----> 3 df = pd.dataframe()
#       4 df.head()
#
# AttributeError: module 'pandas' has no attribute 'dataframe'

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd

df = pd.read_html("https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table", header=0, index_col=0)
summer = df[1].iloc[:, :5]

summer.columns=['Num', 'Gold','Silver','Bronze', 'Total'] # 표의 컬럼 이름 정의
summer.sort_values('Gold', ascending=False) # ‘금’ 숫자를 기준으로 정렬
summer.to_excel("하계올림픽메달.xlsx")

# %%
import tensorflow as tf

tf.keras.optimizers.schedules.ExponentialDecay(
  initial_learning_rate, decay_steps, decay_rate, staircase=False, name=None
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-ab3ca52edd43> in <module>()
#       2
#       3 tf.keras.optimizers.schedules.ExponentialDecay(
# ----> 4   initial_learning_rate, decay_steps, decay_rate, staircase=False, name=None
#       5 )
#
# NameError: name 'decay_steps' is not defined

# %%
initial_learning_rate = 0.1
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
  initial_learning_rate,
  decay_steps=100000,
  decay_rate=0.96,
  staircase=True)

model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=lr_schedule),
  loss='sparse_categorical_crossentropy',
  metrics=['accuracy'])

model.fit(data, labels, epochs=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-6ad40c2bd124> in <module>()
#       6   staircase=True)
#       7
# ----> 8 model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=lr_schedule),
#       9   loss='sparse_categorical_crossentropy',
#      10   metrics=['accuracy'])
#
# NameError: name 'model' is not defined

# %%
W = np.random.randn(fan_in, fan_out)/np.sqrt(fan_in)

W = np.random.randn(fan_in, fan_out)/np.sqrt(fan_in/2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-665c2e7db665> in <module>()
# ----> 1 W = np.random.randn(fan_in, fan_out)/np.sqrt(fan_in)
#       2
#       3 W = np.random.randn(fan_in, fan_out)/np.sqrt(fan_in/2)
#
# NameError: name 'np' is not defined

# %%
# Standalone usage:
initializer = tf.keras.initializers.GlorotUniform()
values = initializer(shape=(2, 2))
# Usage in a Keras layer:
initializer = tf.keras.initializers.GlorotUniform()
layer = tf.keras.layers.Dense(3, kernel_initializer=initializer)
# Usage in a Keras layer:
layer = tf.keras.layers.Dense(3, kernel_initializer='glorot_uniform')

# %%
tf.keras.optimizers.Adam(
learning_rate=0.001, beta_1=0.9, beta_2=0.999,
 epsilon=1e-07, amsgrad=False, name='Adam', **kwargs
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-9c8be8885d72> in <module>()
#       1 tf.keras.optimizers.Adam(
#       2 learning_rate=0.001, beta_1=0.9, beta_2=0.999,
# ----> 3  epsilon=1e-07, amsgrad=False, name='Adam', **kwargs
#       4 )
#
# NameError: name 'kwargs' is not defined

# %%
import matplotlib.pyplot as plt


fashion_mnist = tf.keras.datasets.fashion_mnist
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
X_train, X_test = X_train / 255.0, X_test / 255.0

class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

print(f"train data shape={X_train.shape}, len={len(y_train)}")
print(f"test data shape={X_test.shape}, len={len(y_test)}")

plt.figure(figsize=(10, 10))
for i in range(30):
  plt.subplot(5, 6, i+1)
  plt.xticks([])
  plt.yticks([])
  plt.imshow(X_train[i], cmap=plt.cm.binary)
  plt.xlabel(class_names[y_train[i]])
plt.show()
# Out:
# train data shape=(60000, 28, 28), len=60000
# test data shape=(10000, 28, 28), len=10000
