# %%
import folium
import pandas as pd
import matplotlib.font_manager as fm

map_osm = folium.Map(location=[36.625529, 127.455872], zoom_start=16)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrap
# ...

# %%
map_osm = folium.Map(location=[36.625529, 127.455872], zoom_start=16, tiles="Stamen Toner")
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrap
# ...

# %%
import matplotlib.font_manager as fm
import numpy as np
import pandas as pd
import pandas as pd
import seaborn as sns
import win32com.client

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
plt.rcParams["figure.figsize"] = (20,10)

plt.rc('font', family='NanumGothic') # For Windows
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams.update({'font.size': 15})
print(plt.rcParams['font.family'])

sns.set(font="NanumGothic", 
        rc={"axes.unicode_minus":False},
        style='darkgrid')

map_osm = folium.Map(location=[36.625529, 127.455872], zoom_start=16)
tooltip = "Click me!"
folium.Marker([36.625529, 127.455872], popup="충북대학교 자연대 5 호관", tooltip=tooltip).add_to(map_osm)
folium.Marker([36.627549, 127.458812], popup="충북대학교 제 2 학생회관", icon=folium.Icon(color='red'),tooltip=tooltip).add_to(map_osm)
map_osm
# Out:
# ['Malgun Gothic']
# ...

# %%
map_osm = folium.Map(location=[36.625529, 127.455872], zoom_start=16)
tooltip = "Click me!"
folium.CircleMarker([36.625529, 127.455872], radius=30, color="red", fill = True, popup="충북대학교 자연대 5 호관", tooltip=tooltip).add_to(map_osm)
folium.CircleMarker([36.627549, 127.458812], radius=50, color="blue", fill = False, popup="충북대학교 제 2 학생회관", tooltip=tooltip).add_to(map_osm)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrap
# ...

# %%
office_pos = pd.read_excel("office_position.xlsx")
office_pos
# Out:
#    office_name    code        lat         lon  size0
# 0         강원지사  314100  37.528009  129.117350      5
# 1   강원지사 속초출장소  314110  38.190335  128.594417      3
# 2         경북지사  328000  36.051625  129.377881     15
# 3         고흥지사  325000  34.528254  127.139451     10
# 4         목포지사  322000  34.782800  126.384143     11
# 5         보령지사  316000  36.327164  126.511705     12
# 6           본사  290000  36.514734  127.242779     18
# 7         부산지사  310000  35.062551  129.012728     16
# 8   부산지사 울산출장소  310100  38.190385  128.594449      7
# 9         사천지사  334000  34.926658  128.068429     10
# 10        서울지사  311000  37.530299  126.919601      4
# 11        속초지사  318000  38.190133  128.594316      5
# 12        여수지사  324000  34.754750  127.709117     14
# 13        완도지사  326000  34.316500  126.760739     15
# 14        울산지사  315000  35.497589  129.429949     15
# 15        인천지사  312000  37.459008  126.631540     20
# 16        전북지사  320000  35.959562  126.709458     13
# ...

# %%
map_osm = folium.Map(location=[36.514734, 127.242779], zoom_start=6)
num_offices = office_pos.shape[0]
for i in range(num_offices):
    lat = office_pos.lat[i]
    lon = office_pos.lon[i]
    name = office_pos.office_name[i]
    size = int(office_pos.size0[i])
    folium.CircleMarker(location=[lat, lon], 
                       popup=name, radius=size,
                       color="blue", fill=True).add_to(map_osm)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrap
# ...

# %%
import branca.colormap as cm

colormap = cm.LinearColormap(colors=["red", "black", "blue"])
colormap
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#ff0000ff;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#fe0000ff;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#fd0000ff;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#fc0000ff;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#fb0000ff;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#fa0000ff;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#f90000ff;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#f80000ff;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#f70000ff;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#f60000ff;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#f50000ff;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#f40000ff;stroke-width:3;" /><line x1="12" y1="0" x2="12" 
# ...

# %%
map_osm = folium.Map(location=[36.514734, 127.242779], zoom_start=6)
num_offices = office_pos.shape[0]
colormap = cm.LinearColormap(colors=["red", "black", "blue"],
                             vmin=0, vmax=20, index=[0,10,20])

for i in range(num_offices):
    lat = office_pos.lat[i]
    lon = office_pos.lon[i]
    name = office_pos.office_name[i]
    size = int(office_pos.size0[i])
    folium.CircleMarker(location=[lat, lon], 
                       popup=name, radius=size,
                       color=colormap(i), fill=True).add_to(map_osm)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrap
# ...

# %%
colormap(.25)
# Out:
# '#7f0000ff'

# %%
import folium
import json
map_osm = folium.Map(location=[36.514734, 127.242779], zoom_start=10)
rfile = open("skorea_provinces_geo_simple.json", "r", encoding="utf-8").read()
jsonData = json.loads(rfile)
jsonData
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'code': '39',
#     'name': '제주특별자치도',
#     'name_eng': 'Jeju-do',
#     'base_year': '2013'},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[126.95749379078595, 33.52245641407977],
#        [126.97319896844937, 33.49875407762396],
#        [126.96872405188999, 33.48622329800168],
#        [126.94954584505405, 33.489544759407586],
#        [126.94279608185538, 33.50103054305068],
#        [126.95749379078595, 33.52245641407977]]],
#      [[[126.7825845509244, 33.56393550760943],
#        [126.8018582544952, 33.55370235630926],
#        [126.82997198813513, 33.556850838139745],
#        [126.8331417008612, 33.543008206660225],
#        [126.85956040109559, 33.523745962792475],
#        [126.87389326757639, 33.528409852451844],
#        [126.90448695242354, 33.52306487302841],
#        [126.91799070614931, 33.49833730982538],
#        [126.90673163147841, 33.48381434309957],
# ...

# %%
folium.GeoJson(jsonData, name="json_data").add_to(map_osm)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrap
# ...

# %%
import requests
import json
import folium

searching='충북대학교'
url = 'https://dapi.kakao.com/v2/local/search/keyword.json?query={}'.format(searching)
headers = {
    "Authorization": "KakaoAK a161b6db034e2aed976e9965b5fe1e69"
}
places=requests.get(url, headers = headers).json()['documents']
result = json.loads(str(requests.get(url, headers=headers).text))
result
# Out:
# {'documents': [{'address_name': '충북 청주시 서원구 개신동 12',
#    'category_group_code': 'SC4',
#    'category_group_name': '학교',
#    'category_name': '교육,학문 > 학교 > 대학교',
#    'distance': '',
#    'id': '11312845',
#    'phone': '043-261-2114',
#    'place_name': '충북대학교 개신캠퍼스',
#    'place_url': 'http://place.map.kakao.com/11312845',
#    'road_address_name': '충북 청주시 서원구 충대로 1',
#    'x': '127.45650111773608',
#    'y': '36.62941283907122'},
#   {'address_name': '충북 청주시 서원구 개신동 62',
#    'category_group_code': 'HP8',
#    'category_group_name': '병원',
#    'category_name': '의료,건강 > 병원 > 대학병원',
#    'distance': '',
#    'id': '8117067',
#    'phone': '043-269-6114',
#    'place_name': '충북대학교병원',
#    'place_url': 'http://place.map.kakao.com/8117067',
#    'road_address_name': '충북 청주시 서원구 1순환로 776',
#    'x': '127.4614339234',
#    'y': '36.6241672794444'},
#   {'address_name': '충북 청주시 흥덕구 복대동 680',
#    'category_group_code': '',
#    'category_group_name': '',
# ...

# %%
if len(result['documents']) > 0:
    for doc in result['documents']:
        print(doc['category_name'], doc['x'], doc['y'])
else:
    print('No documents')
# Out:
# 교육,학문 > 학교 > 대학교 127.45650111773608 36.62941283907122
# 의료,건강 > 병원 > 대학병원 127.4614339234 36.6241672794444
# 교통,수송 > 입출구 127.452988055796 36.6320539435727
# 교통,수송 > 입출구 127.457077536961 36.6316021777196
# 가정,생활 > 장례 > 장례식장 127.46106920819864 36.62356042787281
# 교육,학문 > 학습시설 > 도서관 127.457425827462 36.6284829303865
# 교육,학문 > 연구소 127.45715555583 36.6251245523312
# 교육,학문 > 학교 > 대학원 127.45385200319527 36.63218942962538
# 교육,학문 > 학교부속시설 127.460978743611 36.6250773813264
# 의료,건강 > 병원 > 응급실 127.462503916778 36.6243721932406
# 교육,학문 > 학교부속시설 127.45652833936 36.6309951194827
# 가정,생활 > 반려동물 > 동물병원 127.455933128026 36.62333418303
# 교육,학문 > 학교부속시설 127.45938736035 36.6281942307494
# 교육,학문 > 학교부속시설 127.457953432572 36.625442290949
# 교육,학문 > 학교부속시설 127.459614098449 36.6242031493929

# %%
import os
import json
import requests

url = 'https://raw.githubusercontent.com/python-visualization/folium/master/examples/data'
vis1 = json.loads(requests.get(f'{url}/vis1.json').text)
vis2 = json.loads(requests.get(f'{url}/vis2.json').text)
vis3 = json.loads(requests.get(f'{url}/vis3.json').text)


m = folium.Map(
    lication=[46.3014, -123.7390],
    zoom_start=7,
    tiles='Stamen Terrain'
)

folium.Marker(
    location=[47.3489, -124.708],
    popup=folium.Popup(max_width=450).add_child(
        folium.Vega(vis1, width=450, height=250))
).add_to(m)

folium.Marker(
    location=[44.639, -124.5339],
    popup=folium.Popup(max_width=450).add_child(
        folium.Vega(vis2, width=450, height=250))
).add_to(m)

folium.Marker(
    location=[44.216, -124.1280],
    popup=folium.Popup(max_width=450).add_child(
        folium.Vega(vis3, width=450, height=250))
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-2.1.0.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapc
# ...

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/python-visualization/folium/master/examples/data'
state_geo = f'{url}/us-states.json'
state_unemployment = f'{url}/US_Unemployment_Oct2012.csv'
state_data = pd.read_csv(state_unemployment)
state_data
# Out:
#    State  Unemployment
# 0     AL           7.1
# 1     AK           6.8
# 2     AZ           8.1
# 3     AR           7.2
# 4     CA          10.1
# 5     CO           7.7
# 6     CT           8.4
# 7     DE           7.1
# 8     FL           8.2
# 9     GA           8.8
# 10    HI           5.4
# 11    ID           6.6
# 12    IL           8.8
# 13    IN           8.4
# 14    IA           5.1
# 15    KS           5.6
# 16    KY           8.1
# 17    LA           5.9
# 18    ME           7.2
# 19    MD           6.8
# 20    MA           6.7
# 21    MI           9.1
# 22    MN           5.6
# 23    MS           9.1
# 24    MO           6.7
# 25    MT           5.8
# 26    NE           3.9
# 27    NV          10.3
# 28    NH           5.7
# 29    NJ           9.6
# 30    NM           6.8
# 31    NY           8.4
# 32    NC           9.4
# 33    ND           3.2
# 34    OH           6.9
# 35    OK           5.2
# 36    OR           8.5
# 37    PA           8.0
# 38    RI          10.1
# ...

# %%
m = folium.Map(location=[48, -102], zoom_start=3)

folium.Choropleth(
    geo_data=state_geo,
    name='choropleth',
    data=state_data,
    columns=['State', 'Unemployment'],
    key_on='feature.id',
    fill_color='YIGn',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Unemployment Rate (%)'   
).add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-4259f6fb81f3> in <module>
#      10     fill_opacity=0.7,
#      11     line_opacity=0.2,
# ---> 12     legend_name='Unemployment Rate (%)'
#      13 ).add_to(m)
#      14
#
# C:\ProgramData\Anaconda3\lib\site-packages\folium\features.py in __init__(self, geo_data, data, columns, key_on, bins, fill_color, nan_fill_color, fill_opacity, nan_fill_opacity, line_color, line_weight, line_opacity, name, legend_name, overlay, control, show, topojson, smooth_factor, highlight, **kwargs)
#    1139         fill_color = fill_color or ('blue' if data is None else 'Blues')
#    1140
# -> 1141         if data is not None and not color_brewer(fill_color):
#    1142             raise ValueError('Please pass a valid color brewer code to '
#    1143                              'fill_local. See docstring for valid codes.')
#
# ...

# %%
bins = list(state_data['Unemployment'].quantile([0, 0.25, 0.5, 0.75, 1]))

m = folium.Map(lacation=[48, -102], zoom_start=3)

folium.Choropleth(
    geo_data=state_geo,
    data=state_data,
    columns=['State', 'Unemployment'],
    key_on
)
